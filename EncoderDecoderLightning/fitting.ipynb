# %%
import lean_dojo

from datasetPreprocessing import parse_concatenated_json
# Out:
# /Users/artem.semidetnov/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Experimenting
import json
from tqdm import tqdm

data_path = f"/Users/artem.semidetnov/Documents/Predictor/EncoderDecoderLightning/DatasetCode/dataset/test.json"
data = []

for thm in tqdm(parse_concatenated_json(data_path)):
    data.append(
        {
        "exp_type": thm["Expected type"], # = state
        "expression": thm["Expression"], # = tactic
        "premises": thm["Premises"], # = premises
        "context": thm["Context"], # = ?
        }
        )
print(data[0])
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 395726.39it/s]
# ...

# %%
# !python3 -m EncoderDecoderLightning.main fit -c cli_attempt.yaml
# Out:
# /Users/artem.semidetnov/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2025-12-08 15:29:19.499 | INFO     | __main__:main:23 - PID: 80274
# Seed set to 3407
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# ...
